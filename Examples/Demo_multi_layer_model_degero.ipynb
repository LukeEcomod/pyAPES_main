# %% [markdown]
# ### pyAPES_MLM: Multi-layer soil-vegetation-atmosphere transfer model
#
# Demo how to:
# 1. Set-up the model
# 1. Run the model
# 1. Retrieve the results using xarray

# %%
# setting path
import sys
import os

from dotenv import load_dotenv
load_dotenv()
pyAPES_main_folder = os.getenv('pyAPES_main_folder')
sys.path.append(pyAPES_main_folder)
os.chdir(pyAPES_main_folder)

# %% [markdown]
# ### Import modules

# %%
# function to read forcing data. See 'forcing/forcing_info.txt' for model forcing variable names and units!
from pyAPES.utils.iotools import read_forcing

# import the multi-layer model (mlm) driver
from pyAPES.pyAPES_MLM import driver

eps = 1e-16

# %% [markdown]
# ### Read model parameter dictionaries
#
# - mlm setup (parameterization, forcing file & run info) defined in: pyAPES.models.mlm_parameters
# - output variables & logger configuration defined in: pyAPES.models.mlm_outputs. This is read by driver

# %%
# import parameter dictionaries
from pyAPES.parameters.mlm_parameters_SE_Deg import gpara, cpara, spara # model configuration, canopy parameters, soil parameters

# %%
params = {
    'general': gpara,
    'canopy': cpara,
    'soil': spara
}
from pyAPES.parameters.parameter_tools import get_parameter_list
tasks = get_parameter_list(params, 'degero_snow')

# %% [markdown]
# ### Read forcing data and compile input for driver
#
# - forcing is read into pd.DataFrame. Units must be correct!
# - create parameter dictionary and provide it to driver

# %%
snowmod = 'fsm2'
cpara['forestfloor']['snowpack']['snow_model'] = snowmod # 'fsm2' or 'degreeday'

#gpara['forc_filename'] = f'{pyAPES_main_folder}/forcing/SE-Deg/SE-Deg_forcing_2021-2023.dat'
gpara['forc_filename'] = f'{pyAPES_main_folder}/forcing/Degero/Degero_forcing_2021-2023.dat'

forcing = read_forcing(
    forcing_file=gpara['forc_filename'],
    start_time=gpara['start_time'],
    end_time=gpara['end_time'],
    dt=gpara['dt']
)

params = {
    'general': gpara,   # model configuration
    'canopy': cpara,    # planttype, micromet, canopy, bottomlayer parameters
    'soil': spara,      # soil heat and water flow parameters
    'forcing': forcing  # forging data
}

# %% [markdown]
# ### Run the model

# %%
resultfile, Model = driver(parameters=params,
                           create_ncf=True,
                           result_file= 'testrun.nc'
                          )
# Out:
# INFO pyAPES.pyAPES_MLM driver pyAPES_MLM simulation started. Number of simulations: 1
# INFO pyAPES.soil.water __init__ Water balance in soil solved using: EQUILIBRIUM & HOOGHOUDT
# INFO pyAPES.soil.heat __init__ Soil heat balance solved.
# INFO pyAPES.canopy.mlm_canopy __init__ Eflow: True, WMA: False, Ebal: True
# INFO pyAPES.microclimate.radiation __init__ Shortwave radiation model: ZHAOQUALLS
# INFO pyAPES.microclimate.radiation __init__ Longwave radiation model: ZHAOQUALLS
# INFO pyAPES.canopy.forestfloor __init__ Forestfloor has 1 bottomlayer types
# INFO pyAPES.utils.iotools save_parameters_yaml Parameters saved to: /Users/jpnousu/Models/pyAPES_main/inputs/testrun.yml
# INFO pyAPES.pyAPES_MLM driver Running simulation number (start time 2026-05-22 12:44): 0
# INFO pyAPES.pyAPES_MLM run Running simulation 0
# 0%..
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/organiclayer.py:1599: RuntimeWarning: invalid value encountered in scalar power
#   Psi = -1e-2 / alfa*(s**(1.0 / m) - 1.0)**(1.0 / n)  # m
# 10%.. 20%.. 30%.. 40%.. 50%.. 60%.. 70%.. 80%..
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:221: RuntimeWarning: overflow encountered in exp
#   Kc = 404.9 * np.exp(79430.0*(Tk_minus_TN) / (TN_GAS_CONSTANT_Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:379: RuntimeWarning: overflow encountered in exp
#   NOM = np.exp(Ha_v * T_ratio) * (1.0 + np.exp((TN*Sd_v - Hd_v) / TN_GAS_CONSTANT))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:380: RuntimeWarning: overflow encountered in exp
#   DENOM = 1.0 + np.exp((T*Sd_v - Hd_v) * inv_T_GAS_CONSTANT)
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:381: RuntimeWarning: invalid value encountered in divide
#   Vcmax = Vcmax0 * NOM / DENOM
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:388: RuntimeWarning: overflow encountered in exp
#   NOM = np.exp(Ha_j * T_ratio) * (1.0 + np.exp((TN*Sd_j - Hd_j) / TN_GAS_CONSTANT))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:389: RuntimeWarning: overflow encountered in exp
#   DENOM = 1.0 + np.exp((T*Sd_j - Hd_j) * inv_T_GAS_CONSTANT)
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:390: RuntimeWarning: invalid value encountered in divide
#   Jmax = Jmax0 * NOM / DENOM
# 90%..
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:572: RuntimeWarning: invalid value encountered in divide
#   M = volumetric_liquid_content / (porosity - volumetric_ice_content)
# /Users/jpnousu/Models/pyAPES_main/pyAPES/soil/heat.py:484: RuntimeWarning: overflow encountered in exp
#   wice = wtot*(1.0 - np.exp(-(To - T) / fp))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/organiclayer.py:1664: RuntimeWarning: overflow encountered in exp
#   return 611.0 * np.exp((17.502 * temperature) / (temperature + 240.97))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:306: RuntimeWarning: overflow encountered in exp
#   DENOM = (1.0 + np.exp((T*Sd - Hd) / (T*R)))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:317: RuntimeWarning: overflow encountered in exp
#   DENOM = (1.0 + np.exp((T*Sd - Hd) / (T*R)))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/organiclayer.py:1664: RuntimeWarning: overflow encountered in scalar multiply
#   return 611.0 * np.exp((17.502 * temperature) / (temperature + 240.97))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:227: RuntimeWarning: overflow encountered in exp
#   Tau_c = 42.75 * np.exp(37830*(Tk - TN) / (TN * R * Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:230: RuntimeWarning: overflow encountered in exp
#   Kc = 404.9 * np.exp(79430.0*(Tk - TN) / (TN * R * Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:231: RuntimeWarning: overflow encountered in exp
#   Ko = 2.784e5 * np.exp(36380.0*(Tk - TN) / (TN * R * Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:294: RuntimeWarning: overflow encountered in exp
#   Gamma_star = 42.75 * np.exp(37830*(T - T0) / (T0 * R * T))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:305: RuntimeWarning: overflow encountered in exp
#   NOM = np.exp(Ha * (T - T0) / (R*T0*T)) * (1.0 + np.exp((T0*Sd - Hd) / (T0*R)))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:307: RuntimeWarning: invalid value encountered in scalar divide
#   Vcmax = Vcmax25 * NOM / DENOM
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:316: RuntimeWarning: overflow encountered in exp
#   NOM = np.exp(Ha * (T - T0) / (R*T0*T)) * (1.0 + np.exp((T0*Sd - Hd) / (T0*R)))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:318: RuntimeWarning: invalid value encountered in scalar divide
#   Jmax = Jmax25*NOM / DENOM
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:324: RuntimeWarning: overflow encountered in exp
#   Rd = Rd25 * np.exp(Ha*(T - T0) / (T0 * R * T))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/bottomlayer/carbon.py:90: RuntimeWarning: All-NaN axis encountered
#   err = np.nanmax(abs(Cc - Cco))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:218: RuntimeWarning: overflow encountered in exp
#   Tau_c = 42.75 * np.exp(37830*(Tk_minus_TN) / (TN_GAS_CONSTANT_Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:222: RuntimeWarning: overflow encountered in exp
#   Ko = 2.784e5 * np.exp(36380.0*(Tk_minus_TN) / (TN_GAS_CONSTANT_Tk))
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:372: RuntimeWarning: overflow encountered in exp
#   Gamma_star = 42.75 * np.exp(37830 * T_ratio)
# /Users/jpnousu/Models/pyAPES_main/pyAPES/leaf/photo.py:394: RuntimeWarning: overflow encountered in exp
#   Rd = Rd0 * np.exp(Ha_rd * T_ratio)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 resultfile, Model = driver(parameters=params,
#       2                            create_ncf=True,
#       3                            result_file= 'testrun.nc'
#       4                           )
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:149, in driver(parameters, create_ncf, result_file)
#     146 logger.info('Running simulation number (start time %s): %s' % (
#     147             time.strftime('%Y-%m-%d %H:%M'), task.Nsim))
#     148 running_time = time.time()
# --> 149 results = task.run()
#     150 logger.info('Running time %.2f seconds' %
#     151             (time.time() - running_time))
#     152 write_ncf(nsim=task.Nsim, results=results, ncf=ncf)
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:282, in MLM_model.run(self, write_interval)
#     279 time0 = time.time()
#     281 # print('RUNNING')
# --> 282 self._run_steps(0, self.Nsteps, self.results, index_offset=0)
#     283 print('100%')
#     285 # Append static grid and metadata outputs (no time dimension)
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:384, in MLM_model._run_steps(self, k_start, k_end, results, index_offset)
#     370 canopy_parameters = {
#     371     'soil_depth': self.soil.grid['z'][0],   # [m]
#     372     'soil_porosity': self.soil.heat.porosity,  # [m3 m-3]
#    (...)    380     'date': self.forcing.index[k]   # pd.datetime
#     381 }
#     383 # call self.canopy_model.run to solve above-ground part
# --> 384 out_canopy, out_planttype, out_ffloor, out_groundtype = self.canopy_model.run(
#     385     dt=self.dt,
#     386     forcing=canopy_forcing,
#     387     parameters=canopy_parameters
#     388 )
#     390 # --- Soil model  ---
#     391 # compile forcing for Soil: potential infiltration and evaporation are at from ground surface
#     392 # water fluxes must be in [m s-1]
#     393 soil_forcing = {
#     394     'potential_infiltration': out_ffloor['throughfall'] / WATER_DENSITY,
#     395     'potential_evaporation': ((out_ffloor['soil_evaporation'] +
#    (...)    400     'ground_heat_flux': -out_ffloor['ground_heat'],
#     401     'date': self.forcing.index[k]}
#
# File ~/Models/pyAPES_main/pyAPES/canopy/mlm_canopy.py:329, in CanopyModel.run(self, dt, forcing, parameters)
#     323     lw_params = {
#     324         'LAIz': self.lad * self.dz,
#     325         'ff_emissivity': self.forestfloor.emissivity
#     326     }
#     328     # solve LW profiles
# --> 329     radiation_profiles['lw'] = self.radiation.longwave_profiles(
#     330         forcing=lw_forcing,
#     331         parameters=lw_params
#     332     )
#     334 # --- heat, h2o and co2 source terms
#     335 for key in sources.keys():
#
# File ~/Models/pyAPES_main/pyAPES/microclimate/radiation.py:176, in Radiation.longwave_profiles(self, forcing, parameters)
#     165     lw_leaf, lw_dn, lw_up, gr = canopy_lw(
#     166         LAIz=parameters['LAIz'],
#     167         Clump=self.clump,
#    (...)    172         leaf_emi=self.leaf_emi
#     173     )
#     175 if self.LWmodel == 'ZHAOQUALLS':
# --> 176     lw_leaf, lw_dn, lw_up, gr = canopy_lw_ZhaoQualls(
#     177         LAIz=parameters['LAIz'],
#     178         Clump=self.clump,
#     179         x=self.leaf_angle,
#     180         Tleaf=forcing['leaf_temperature'],
#     181         LWdn0=forcing['lw_in'],
#     182         LWup0=forcing['lw_up'],
#     183         leaf_emi=self.leaf_emi,
#     184         soil_emi=parameters['ff_emissivity']
#     185     )
#     187 # ADD OTHER MODELS??
#     189 results = {
#     190     'net_leaf': lw_leaf,
#     191     'down': lw_dn,
#     192     'up': lw_up,
#     193     'radiative_conductance': gr
#     194 }
#
# File ~/Models/pyAPES_main/pyAPES/microclimate/radiation.py:1134, in canopy_lw_ZhaoQualls(LAIz, Clump, x, Tleaf, LWdn0, LWup0, leaf_emi, soil_emi, PlotFigs)
#    1131 # ---- solve a*LW = D
#    1132 if soil_emi <= 1.0 and leaf_emi <= 1.0:
#    1133     # LW = tridiag(A,B,C,D)
# -> 1134     LW = solve_banded((1,1),np.vstack((C,B,A)),D)
#    1135 else:
#    1136     matrix = np.zeros([2*M+2, 2*M+2])
#
# File /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/scipy/linalg/_basic.py:839, in solve_banded(l_and_u, ab, b, overwrite_ab, overwrite_b, check_finite)
#     765 """
#     766 Solve the equation ``a @ x = b`` for ``x``, where ``a`` is the banded matrix
#     767 defined by `ab`.
#    (...)    836
#     837 """
#     838 (nlower, nupper) = l_and_u
# --> 839 return _solve_banded(nlower, nupper, ab, b, overwrite_ab=overwrite_ab,
#     840                      overwrite_b=overwrite_b, check_finite=check_finite)
#
# File /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/scipy/_lib/_util.py:1181, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1179 # Early exit if call is not batched
#    1180 if not any(batch_shapes):
# -> 1181     return f(*arrays, *other_args, **kwargs)
#    1183 # Determine broadcasted batch shape
#    1184 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/scipy/linalg/_basic.py:846, in _solve_banded(nlower, nupper, ab, b, overwrite_ab, overwrite_b, check_finite)
#     843 @_apply_over_batch(('nlower', 0), ('nupper', 0), ('ab', 2), ('b', '1|2'))
#     844 def _solve_banded(nlower, nupper, ab, b, overwrite_ab, overwrite_b, check_finite):
#     845     a1 = _asarray_validated(ab, check_finite=check_finite, as_inexact=True)
# --> 846     b1 = _asarray_validated(b, check_finite=check_finite, as_inexact=True)
#     848     # Validate shapes.
#     849     if a1.shape[-1] != b1.shape[0]:
#
# File /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/scipy/_lib/_util.py:468, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     466         raise ValueError('masked arrays are not supported')
#     467 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 468 a = toarray(a)
#     469 if not objects_ok:
#     470     if a.dtype is np.dtype('O'):
#
# File /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/numpy/lib/_function_base_impl.py:673, in asarray_chkfinite(a, dtype, order)
#     671 a = asarray(a, dtype=dtype, order=order)
#     672 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 673     raise ValueError(
#     674         "array must not contain infs or NaNs")
#     675 return a
#
# ValueError: array must not contain infs or NaNs

# %% [markdown]
# ### Model run completed and results are in NetCDF-file.
#
# ### Read results using xarray
# - we use function 'read_results' from pyAPES.utils.utils
#
# - see https://docs.xarray.dev/en/stable/

# %%
from pyAPES.utils.iotools import read_results
import matplotlib.pyplot as plt

# read simulation restuls to xarray dataset
results = read_results(resultfile)

# %%
plt.figure()
results['ffloor_snow_water_equivalent'].plot()

# %%
plt.figure()
results['ffloor_snow_water_equivalent'].plot()

# %%
# %matplotlib widget
plt.figure()
results['soil_temperature'][:,0,0].plot()
results['gt_surface_temperature'][:,0,0].plot()
#results['gt_temperature'][:,0,0].plot()
#results['canopy_temperature'][:,0,0].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Print resuts metadata:
#
# Output variables are those defined at pyAPES.parameters.mlm_outputs'. Each variable contains one or several of following dimensions:
#
# - date --> time dimension
# - simulation --> simulation number. If there is only one, remember that it has index 0!
# - canopy --> canopy and air layers. Index is 0 at ground and increases upwards
# - planttype --> planttypes defined in mlm_parameters. Index follows the order in dict cpara['planttypes'])
# - soil -> soil layers. Index 0 is at the top and increases downwards (nr soil layers, 0 at top)
# - groundtype --> groundtypes at forestfloor. Defined in mlm_parameters. Index follows the order in dict: cpara['forestfloor']['bottom_layer_types']

# %%
print(results)

# print list of all variables:
#vars = list(results.data_vars)
#for v in vars:
#    print(v)
# Out:
# <xarray.Dataset> Size: 83MB
# Dimensions:                               (date: 10177, simulation: 1,
#                                            canopy: 20, planttype: 2, soil: 44,
#                                            groundtype: 1)
# Coordinates:
#   * date                                  (date) datetime64[ns] 81kB 2021-10-...
#   * simulation                            (simulation) int64 8B 0
#   * canopy                                (canopy) float32 80B 0.0 ... 10.0
#   * soil                                  (soil) float32 176B -0.005 ... -1.95
# Dimensions without coordinates: planttype, groundtype
# Data variables: (12/166)
#     forcing_air_temperature               (date, simulation) float32 41kB ...
#     forcing_precipitation                 (date, simulation) float32 41kB ...
#     forcing_pressure                      (date, simulation) float32 41kB ...
#     forcing_h2o                           (date, simulation) float32 41kB ...
#     forcing_co2                           (date, simulation) float32 41kB ...
#     forcing_wind_speed                    (date, simulation) float32 41kB ...
#     ...                                    ...
#     gt_water_content                      (date, simulation, groundtype) float32 41kB ...
#     gt_volumetric_water                   (date, simulation, groundtype) float32 41kB ...
#     gt_water_storage                      (date, simulation, groundtype) float32 41kB ...
#     gt_water_potential                    (date, simulation, groundtype) float32 41kB ...
#     gt_hydraulic_conductivity             (date, simulation, groundtype) float32 41kB ...
#     gt_thermal_conductivity               (date, simulation, groundtype) float32 41kB ...
# Attributes:
#     description:  pyAPES_MLM results
#     history:      created 2026-05-22 12:07:17
#     source:       pyAPES_1.0

# %% [markdown]
# ### Plot some model results

# %%
sim = 0  # in this demo, we have only one simulation (i.e. only one parameter set was used)

# grid variables for plotting
t = results.date  # time
zc = results.canopy_z  # height above ground [m]
zs = results.soil_z  # depth of soil; shown negative [m]

# %% [markdown]
# ### Soil temperature and moisture
#
# - computed using pyAPES.soil - package submodels 'Water' and 'Heat'
# - model state at end of simulation is in: Model.soil.heat & Model.soil.water

# %%
# model state (last timestep)

#soilheat = Model.soil.heat
#vars(soilheat)  # list instance variables

#soilwater = Model.soil.water
#vars(soilwater)

# %%
import numpy as np
var = ['soil_temperature', 'soil_volumetric_water_content']

lyrs = [0, 1, 2, 3, 4] # five top layers
#depths = np.array2string(np.asarray(zs[lyrs]), precision=1, separator=', ')
depths = ['{:.2f} m'.format(k) for k in zs[lyrs]]

fig, ax = plt.subplots(2, 1, figsize=(10,7))

k = 0
for v in var:
    ax[k].plot(t, results[v][:,sim,lyrs], label=depths)
    ax[k].set_ylabel(results[v].attrs['units'])
    ax[k].tick_params(axis='x', labelrotation = 20)
    ax[k].legend(fontsize=8)
    k += 1

# vertical profile at last timestep
fig, ax = plt.subplots(1, 2) #figsize=(10,5))

k = 0
for v in var:
    ax[k].plot(results[v][-1,sim,:], zs)
    ax[k].set_xlabel(results[v].attrs['units'])
    ax[0].set_ylabel('depth (m)')
    k += 1
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Ecosystem-scale fluxes
#
# - ecosystem - atm. fluxes represent the integrated sinks / sources in soil (soil-module), forestfloor (bottomlayer-module) and vegetation (planttype&canopy -modules)
# - comparable to ecosystem - atmosphere exchange
# - affected by current model forcing and sub-model instance state (e.g. Planttype and Canopy LAI, phenology, soil temperature, moisture etc.)

# %%
var = ['forcing_air_temperature', 'forcing_par', 'canopy_NEE', 'canopy_GPP', 
       'canopy_Reco', 'canopy_Rnet', 'canopy_SH', 'canopy_LE', 'ffloor_ground_heat']

fig, ax = plt.subplots(3, 1, figsize=(8,12), sharex=True)

# temperature & par
ax[0].plot(t, results[var[0]][:,sim], 'k--', label=var[0])
ax[0].set_ylabel(results[var[0]].attrs['units'])
ax[0].tick_params(axis='x', labelrotation = 20)
axb = ax[0].twinx()

axb.plot(t, results[var[1]][:,sim], 'r-', label=var[1]) # Par
axb.set_ylabel(results[var[0]].attrs['units'])

# CO2 fluxes
for v in var[2:5]:
    ax[1].plot(t, results[v][:,sim], label=v)

ax[1].set_ylabel('umol m-2 s-1')
ax[1].tick_params(axis='x', labelrotation = 20)
ax[1].legend(fontsize=8)

# energy fluxes
for v in var[5:]:
    ax[2].plot(t, results[v][:,sim], label=v)

ax[2].set_ylabel('W m-2')
ax[2].tick_params(axis='x', labelrotation = 20)
ax[2].legend(fontsize=8)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Ecosystem radiation balance
#
# - net radiation (Rnet) is the sum of net shortwave (SWnet = incoming - reflected) and net longwave (LWnet = incoming - emitted) radiation at canopy top
# - computed via models in pyAPES.microclimate.radiation, called iteratively from pyAPES.canopy.mlm_canopy to account for canopy structure and leaf & forest floor temperature
# - ecosystem albedo can be computed from radiation profiles at uppermost grid point

# %%
# net radiation components at canopy top
var = ['canopy_Rnet','canopy_SWnet', 'canopy_LWnet']
profs = ['canopy_par_down', 'canopy_par_up', 'canopy_nir_down','canopy_nir_up','canopy_lw_down','canopy_lw_up']

fig, ax = plt.subplots(3, 1, figsize=(8,12), sharex=True)

for v in var:
    ax[0].plot(t, results[v][:, sim], label=v)
ax[0].set_ylabel('W m-2')
ax[0].tick_params(axis='x', labelrotation = 20)
ax[0].legend(fontsize=8)    

# lets plot also partitioning of canopy_SWnet and canopy_LWnet.
# -1 is the index of uppermost gridpoint

for v in ['canopy_par_down', 'canopy_nir_down','canopy_lw_down']: # downward
    ax[1].plot(t, results[v][:,sim,-1], '-', label=v)
for v in ['canopy_par_up', 'canopy_nir_up','canopy_lw_up']: # upward
    ax[1].plot(t, results[v][:,sim,-1], '--', label=v)
ax[1].set_ylabel('W m-2')
ax[1].tick_params(axis='x', labelrotation = 20)
ax[1].legend(fontsize=8)

# canopy albedo
eps = 1e-16

# fraction of par on total SW
f_par = results['canopy_par_down'][:,sim,-1] / (results['canopy_par_down'][:,sim,-1] + results['canopy_nir_down'][:,sim,-1] + eps)

alb_par = results['canopy_par_up'][:,sim,-1] / (results['canopy_par_down'][:,sim,-1] + eps)
alb_nir = results['canopy_nir_up'][:,sim,-1] / (results['canopy_nir_down'][:,sim,-1] + eps)
alb_sw = f_par * alb_par + (1 - f_par) * alb_nir
alb_sw = np.maximum(0, np.minimum(1.0, alb_sw))

ax[2].plot(t, alb_sw, '-', label='SW albedo')
ax[2].plot(t, alb_par, '-', label='Par albedo')
ax[2].plot(t, alb_nir, '-', label='Nir albedo')

ax[2].tick_params(axis='x', labelrotation = 20)
ax[2].legend(fontsize=8)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
