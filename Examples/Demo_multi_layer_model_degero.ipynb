# %% [markdown]
# ### pyAPES_MLM: Multi-layer soil-vegetation-atmosphere transfer model
#
# Demo how to:
# 1. Set-up the model
# 1. Run the model
# 1. Retrieve the results using xarray

# %%
# setting path
import sys
import os
import pandas as pd

from dotenv import load_dotenv
load_dotenv()
pyAPES_main_folder = os.getenv('pyAPES_main_folder')
sys.path.append(pyAPES_main_folder)
os.chdir(pyAPES_main_folder)

# %% [markdown]
# ### Import modules

# %%
# function to read forcing data. See 'forcing/forcing_info.txt' for model forcing variable names and units!
from pyAPES.utils.iotools import read_forcing

# import the multi-layer model (mlm) driver
from pyAPES.pyAPES_MLM import driver

eps = 1e-16

# %% [markdown]
# ### Read model parameter dictionaries
#
# - mlm setup (parameterization, forcing file & run info) defined in: pyAPES.models.mlm_parameters
# - output variables & logger configuration defined in: pyAPES.models.mlm_outputs. This is read by driver

# %%
# import parameter dictionaries
from pyAPES.parameters.mlm_parameters_SE_Deg import gpara, cpara, spara # model configuration, canopy parameters, soil parameters

# %% [markdown]
# ### Read forcing data and compile input for driver
#
# - forcing is read into pd.DataFrame. Units must be correct!
# - create parameter dictionary and provide it to driver

# %%
snowmod = 'fsm2'
site = 'degero'
cpara['forestfloor']['snowpack']['snow_model'] = snowmod # 'fsm2' or 'degreeday'

#gpara['forc_filename'] = f'{pyAPES_main_folder}/forcing/Degero/Degero_forcing_2021-2023.dat'
#gpara['forc_filename'] = f'{pyAPES_main_folder}/forcing/SE-Deg/SE-Deg_forcing_2021-2023.dat'
gpara['start_time'] = '2021-09-01'
gpara['end_time'] = '2022-09-01'

forcing = read_forcing(
    forcing_file=gpara['forc_filename'],
    start_time=gpara['start_time'],
    end_time=gpara['end_time'],
    dt=gpara['dt']
)

params = {
    'general': gpara,   # model configuration
    'canopy': cpara,    # planttype, micromet, canopy, bottomlayer parameters
    'soil': spara,      # soil heat and water flow parameters
    'forcing': forcing  # forcing data
}

# %% [markdown]
# ### Run the model

# %%
resultfile, Model = driver(parameters=params,
                           create_ncf=True,
                           result_file= 'testrun.nc'
                          )
# Out:
# INFO pyAPES.pyAPES_MLM driver pyAPES_MLM simulation started. Number of simulations: 1
# INFO pyAPES.soil.water __init__ Water balance in soil solved using: EQUILIBRIUM & HOOGHOUDT
# INFO pyAPES.soil.heat __init__ Soil heat balance solved.
# INFO pyAPES.canopy.mlm_canopy __init__ Eflow: True, WMA: True, Ebal: True
# INFO pyAPES.microclimate.radiation __init__ Shortwave radiation model: ZHAOQUALLS
# INFO pyAPES.microclimate.radiation __init__ Longwave radiation model: ZHAOQUALLS
# INFO pyAPES.canopy.forestfloor __init__ Forestfloor has 1 bottomlayer types
# INFO pyAPES.utils.iotools save_parameters_yaml Parameters saved to: /Users/jpnousu/Models/pyAPES_main/inputs/testrun.yml
# INFO pyAPES.pyAPES_MLM driver Running simulation number (start time 2026-05-29 13:50): 0
# INFO pyAPES.pyAPES_MLM run Running simulation 0
# 0%.. 10%.. 20%.. 30%.. 40%.. RuntimeWarning in Km calculation: divide by zero encountered in divide
#   Tk_minus_TN = [ -30.11       -294.45543085  -28.65470138  -28.99355986  -29.20978463
#   -29.37319588  -29.50511697  -29.61919532  -29.91882907  -30.11
#   -30.11        -30.11        -30.11        -30.11        -30.11
#   -30.11        -30.11        -30.11        -30.11        -30.11      ]
#   Kc = [11.06811044  0.         13.41728389 12.83162318 12.47061345 12.2041637
#  11.99298911 11.81316165 11.35287695 11.06811044 11.06811044 11.06811044
#  11.06811044 11.06811044 11.06811044 11.06811044 11.06811044 11.06811044
#  11.06811044 11.06811044]
#   Ko = [53538.81354942     0.         58472.89461959 57289.74849396
#  56545.80602358 55989.20857632 55543.38192434 55160.36865426
#  54165.37455517 53538.81354942 53538.81354942 53538.81354942
#  53538.81354942 53538.81354942 53538.81354942 53538.81354942
#  53538.81354942 53538.81354942 53538.81354942 53538.81354942]
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# File ~/Models/pyAPES_main/pyAPES/leaf/photo.py:235, in photo_c3_medlyn_farquhar_fast(photop, Qp, T, VPD, ca, gb_c, gb_v, P)
#     234 try:
# --> 235     Km = Kc * (1.0 + O2_IN_AIR / Ko)
#     236 except RuntimeWarning as e:
#
# RuntimeWarning: divide by zero encountered in divide
#
# During handling of the above exception, another exception occurred:
#
# RuntimeWarning                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 resultfile, Model = driver(parameters=params,
#       2                            create_ncf=True,
#       3                            result_file= 'testrun.nc'
#       4                           )
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:149, in driver(parameters, create_ncf, result_file)
#     146 logger.info('Running simulation number (start time %s): %s' % (
#     147             time.strftime('%Y-%m-%d %H:%M'), task.Nsim))
#     148 running_time = time.time()
# --> 149 results = task.run()
#     150 logger.info('Running time %.2f seconds' %
#     151             (time.time() - running_time))
#     152 write_ncf(nsim=task.Nsim, results=results, ncf=ncf)
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:288, in MLM_model.run(self, write_interval)
#     285 time0 = time.time()
#     287 # print('RUNNING')
# --> 288 self._run_steps(0, self.Nsteps, self.results, index_offset=0)
#     289 print('100%')
#     291 # Append static grid and metadata outputs (no time dimension)
#
# File ~/Models/pyAPES_main/pyAPES/pyAPES_MLM.py:395, in MLM_model._run_steps(self, k_start, k_end, results, index_offset)
#     381 canopy_parameters = {
#     382     'soil_depth': self.soil.grid['z'][0],   # [m]
#     383     'soil_porosity': self.soil.heat.porosity,  # [m3 m-3]
#    (...)    391     'date': self.forcing.index[k]   # pd.datetime
#     392 }
#     394 # call self.canopy_model.run to solve above-ground part
# --> 395 out_canopy, out_planttype, out_ffloor, out_groundtype = self.canopy_model.run(
#     396     dt=self.dt,
#     397     forcing=canopy_forcing,
#     398     parameters=canopy_parameters
#     399 )
#     401 # extract and store snow depth for use in next day's run_daily
#     402 if 'snow_depth' in out_ffloor:
#
# File ~/Models/pyAPES_main/pyAPES/canopy/mlm_canopy.py:466, in CanopyModel.run(self, dt, forcing, parameters)
#     462 Rg_total = 0.0
#     463 for pt in self.planttypes:
#     464
#     465     # --- sunlit and shaded leaves gas-exchange and optional energy balance
# --> 466     pt_stats_i, layer_stats_i = pt.run(
#     467         forcing=forcing_pt,
#     468         parameters=parameters_pt,
#     469         controls=controls_pt
#     470     )
#     472     # update source terms
#     473     # in planttype, net uptake >0, here we want sink negative
#     474     sources['co2'] -= layer_stats_i['net_co2']
#
# File ~/Models/pyAPES_main/pyAPES/planttype/planttype.py:386, in PlantType.run(self, forcing, parameters, controls)
#     375 # sunlit & shaded separately
#     376 self.photo_forcing = set_photo_forcing(self.photo_forcing,
#     377                                        forcing['par']['sunlit']['incident'] *
#     378                                        PAR_TO_UMOL,
#    (...)    383                                        gb_v,
#     384                                        forcing['air_pressure'])
# --> 386 results_wet_sl = self.Photo_model.run(self.photo_forcing, self.photop)
#     387 An_wet_sl = results_wet_sl['An']
#     388 Rd_wet_sl = results_wet_sl['Rd']
#
# File ~/Models/pyAPES_main/pyAPES/leaf/photo.py:51, in PhotosynthesisModel.run(self, forcing, photop)
#      49 def run(self, forcing: Dict, photop: Dict) -> Dict:
#      50     if self.photo_model.upper() == 'MEDLYN_FARQUHAR':
# ---> 51         results = photo_c3_medlyn_farquhar_fast(photop,
#      52                                            forcing['Qp'], forcing['T'], forcing['VPD'],
#      53                                            forcing['co2'], forcing['gb_c'], forcing['gb_v'],
#      54                                            P=forcing['air_pressure'])
#      55         results_dict = {k: v for k, v in zip(self.output_names, results)}
#      56     return results_dict
#
# File ~/Models/pyAPES_main/pyAPES/leaf/photo.py:241, in photo_c3_medlyn_farquhar_fast(photop, Qp, T, VPD, ca, gb_c, gb_v, P)
#     239         print(f"  Kc = {Kc}")
#     240         print(f"  Ko = {Ko}")
# --> 241         Km = Kc * (1.0 + O2_IN_AIR / Ko)
#     242 JaQ = Jmax + alpha * Qp  # precompute: appears twice in J formula
#     243 J = (JaQ - np.sqrt(JaQ * JaQ - 4 * theta * Jmax * alpha * Qp)) / (2 * theta)
#
# RuntimeWarning: divide by zero encountered in divide

# %% [markdown]
# ### Model run completed and results are in NetCDF-file.
#
# ### Read results using xarray
# - we use function 'read_results' from pyAPES.utils.utils
#
# - see https://docs.xarray.dev/en/stable/

# %%
from pyAPES.utils.iotools import read_results
import matplotlib.pyplot as plt
resultfile = '/Users/jpnousu/Models/pyAPES_main/results/testrun.nc'
# read simulation restuls to xarray dataset
results = read_results(resultfile)

# %%
met = f'{pyAPES_main_folder}/forcing/Degero/Degero_meteo_2021-2023.dat'
flux = f'{pyAPES_main_folder}/forcing/SE-Deg/SE-Deg_EC_2021-2023.dat'
start = pd.to_datetime(str(results['date'][0].values))
end = pd.to_datetime(str(results['date'][-1].values))
meteo = pd.read_csv(met, sep=';', index_col=0, parse_dates=True)
fluxes = pd.read_csv(flux, sep=';', index_col=0, parse_dates=True)
meteo = meteo[start:end]
meteo['WTD_c'] = meteo['WTD']
meteo.loc[meteo['WTD_c'] < 0, 'WTD_c'] = 0.0
meteo['D_SNOW'] = meteo['D_SNOW']/100
meteo.loc[meteo['D_SNOW'] > 1., 'D_SNOW'] = np.nan
meteo = meteo.resample('D').mean()

binned = pd.cut(meteo['D_SNOW'], bins=100)
most_frequent_bin = binned.value_counts().idxmax()
baseval1 = round((most_frequent_bin.left + most_frequent_bin.right) / 2, 2)
baseval2 = round(meteo['D_SNOW'].median(), 2)
baseval2 = 0.05

meteo['D_SNOW_C'] = meteo['D_SNOW'] - baseval2
meteo.loc[meteo['D_SNOW_C'] < 0., 'D_SNOW_C'] = 0.
meteo.index.name = 'date'

# %%
plot_start = '2021-11-01'
plot_end = '2022-06-01'

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 5), sharex=True)
simulations = {0: 'fsm2', 1: 'degreeday'}

for simu, label in simulations.items():
    results['ffloor_snow_water_equivalent'].sel(simulation=simu).sel(date=slice(plot_start, plot_end)).plot(ax=ax1, label=label)
ax1.legend(loc='upper left')
ax1.set_ylabel('Snow water equivalent [mm]')
ax1.set_title('')

for simu, label in simulations.items():
    results['ffloor_snow_depth'].sel(simulation=simu).sel(date=slice(plot_start, plot_end)).plot(ax=ax2, label=label)
meteo['D_SNOW_C'].resample('D').mean()[plot_start:plot_end].plot(ax=ax2, color='gray', marker='.', linestyle='none', label='obs')
ax2.set_ylabel('Snow depth [m]')
ax2.legend(loc='upper left')
ax2.set_title('')

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
plt.figure()
results['soil_temperature'][:,0,0].plot(label='soil')
results['gt_surface_temperature'][:,0,0].plot(label='gt surface')
forcing['Tair'].plot(label='air')
#results['gt_temperature'][:,0,0].plot(label='gt')
#results['canopy_temperature'][:,0,0].plot(label='canopy')
plt.legend()
# Out:
# /opt/miniconda3/envs/pyapes/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:997: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Print resuts metadata:
#
# Output variables are those defined at pyAPES.parameters.mlm_outputs'. Each variable contains one or several of following dimensions:
#
# - date --> time dimension
# - simulation --> simulation number. If there is only one, remember that it has index 0!
# - canopy --> canopy and air layers. Index is 0 at ground and increases upwards
# - planttype --> planttypes defined in mlm_parameters. Index follows the order in dict cpara['planttypes'])
# - soil -> soil layers. Index 0 is at the top and increases downwards (nr soil layers, 0 at top)
# - groundtype --> groundtypes at forestfloor. Defined in mlm_parameters. Index follows the order in dict: cpara['forestfloor']['bottom_layer_types']

# %%
print(results)

# print list of all variables:
#vars = list(results.data_vars)
#for v in vars:
#    print(v)
# Out:
# <xarray.Dataset> Size: 110MB
# Dimensions:                               (date: 17521, simulation: 1,
#                                            canopy: 20, planttype: 1, soil: 44,
#                                            groundtype: 1)
# Coordinates:
#   * date                                  (date) datetime64[ns] 140kB 2021-09...
#   * simulation                            (simulation) int64 8B 0
#   * canopy                                (canopy) float32 80B 0.0 ... 10.0
#   * soil                                  (soil) float32 176B -0.005 ... -1.95
# Dimensions without coordinates: planttype, groundtype
# Data variables: (12/168)
#     forcing_air_temperature               (date, simulation) float32 70kB ...
#     forcing_precipitation                 (date, simulation) float32 70kB ...
#     forcing_pressure                      (date, simulation) float32 70kB ...
#     forcing_h2o                           (date, simulation) float32 70kB ...
#     forcing_co2                           (date, simulation) float32 70kB ...
#     forcing_wind_speed                    (date, simulation) float32 70kB ...
#     ...                                    ...
#     gt_water_content                      (date, simulation, groundtype) float32 70kB ...
#     gt_volumetric_water                   (date, simulation, groundtype) float32 70kB ...
#     gt_water_storage                      (date, simulation, groundtype) float32 70kB ...
#     gt_water_potential                    (date, simulation, groundtype) float32 70kB ...
#     gt_hydraulic_conductivity             (date, simulation, groundtype) float32 70kB ...
#     gt_thermal_conductivity               (date, simulation, groundtype) float32 70kB ...
# Attributes:
#     description:  pyAPES_MLM results
#     history:      created 2026-05-29 13:23:01
#     source:       pyAPES_1.0
